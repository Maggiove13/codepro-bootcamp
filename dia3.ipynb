# %%
print("holo")
# Out:
# holo

# %%
def saludar():
    print("Hola")

saludar()
# Out:
# Hola

# %% [markdown]
# ## Challenge 1 🤺
#
# Crear una función que imprima la variable palabra.

# %%
# Definir una variable llamada palabra
# CRear una funcion def imprimir_palabra()
    # imprimir la variable palabra
# Llamar a la funcion para ejecutar

palabra = 'Hola'
letra = 'a'

# Estamos definiendo una funcion
def imprimir_letra():
    print(letra)

# Llamamos a una funcion que definimos
imprimir_letra()

def imprimir_palabra():
    print(palabra)

imprimir_palabra()

# %%
# Funcion que recibe 2 numeros y suma:

# Definir 2 variables con int(input()), numero1, numero2 (fuera de la funcion)

# Definir funcion sumar(n1, n2):
    # opcion1: n3 = n1 + n2
    # opcion1: print(n3)
    # opcion2: print(n1 + n2)

def sumar(n1, n2):
    print(n1 + n2)

sumar(2, 2)
# Out:
# 4

# %% [markdown]
# ## Challenge 2 🤺 - 10 min
# Crear una función que `reciba` dos letras `(parámetros)` y que `verifique` si son iguales:
#
# 1. `Si son iguales`, imprimir "Las letras son iguales".
#
# 2. `De lo contrario`, imprimir "Las letras son diferentes".

# %%
# Solucion de Sandro:
letra1= input("ingrese la primera letra")
letra2= input("ingrese la segunda letra")

def comparar_letras(l1, l2):
    if l1 == l2:
        print("las letras son iguales")
    else:
        print("las letras no son iguales")

comparar_letras(letra1, letra2)

# %% [markdown]
# ## RETURN

# %%
def sumar(n1, n2):
    return n1 + n2


# resultado = sumar(5, 8)
# print(resultado)
# Out:
# 4
# <class 'NoneType'>

# %%
def retirar_dinero(dinero):
    return dinero

dinero_retirado = retirar_dinero(50000)
print(f'Este es el dato de dinero_retirado: {dinero_retirado}')

sumar(dinero_retirado, 10000)

# %% [markdown]
# ## Challenge 3 🤺 - 3
#
# Crear una función que reciba `dos parámetros` (una palabra y un número), y que retorne `True` si el `número es igual` a la cantidad de letras de la palabra. En caso contrario, que retorne `False`.
#
# Pista: `cantidad de letras de una palabra en python`

# %%
# Solucion de Tobias:

palabraa = input("escribe una palabra ")
numero = int(input("ingrese un numero "))
def compara(palabraa, numero):
    if len(palabraa) == numero:
        return True
    else:
        return False

compara(palabraa, numero)
# Out:
# True

# %% [markdown]
# ## Challenge 4 🤺 - 20 min
# Crear `función` que revise si una palabra `contiene` una letra. En caso de que la contenga, `retornar` la letra entre corchetes `[]`. De lo contrario, `retornar` solo la letra.

# %%
# Solucion de Liz:

#Paso 1: Pedir al usuario que ingrese una palabra con input.
palabra_ingresada = input("Ingrese una palabra")
condicion = "o"
#Paso 2: definir la funcion.
def comparar_palabra(letra,cond):
     if cond in letra:
       return f'{cond}]'
     else:
        return cond

#Paso 3: llamar a la funcion
comparar_palabra(palabra_ingresada,condicion)

# %%
palabra_a_encontrar = input("Ingresa una palabra")
print(f'Esta es la palabra a encontrar {palabra_a_encontrar}')

palabra_secreta = input("Ingrese palabra secreta")
print(f'Esta es la palabra a encontrar {palabra_secreta}')

lista_de_palabras = list(palabra_a_encontrar)
print(f"La lista es {lista_de_palabras}")
# Out:
# Esta es la palabra a encontrar gordo
# Esta es la palabra a encontrar flaco
# lista ['g', 'o', 'r', 'd', 'o']

# %% [markdown]
# ## Challenge 5 🤺 - 20m
#
# `Pedir al usuario` que ingrese 1 palabra, luego `convertir` esa palabra a una `lista` con sus caracteres con `list()`. Agregar esa lista de caracteres a una lista llamada `palabras_ingresadas`. Repetir el proceso 3 veces. Cada vez que se agregue una lista de caracteres, imprimir la lista `palabras_ingresadas`.
#
#
# Ejemplo del resultado esperado:
#
# ```[['c', 'i', 'e', 'l', 'o']]``` # Al ingresar la primera palabra
#
# ```[['c', 'i', 'e', 'l', 'o'], ['c', 'a', 'l', 'o', 'r']]``` # Al ingresar la segunda palabra
#
# ```[['c', 'i', 'e', 'l', 'o'], ['c', 'a', 'l', 'o', 'r'], ['n', 'u', 'b', 'e', 's']]``` # Al ingresar la tercera palabra

# %%
# definir una variable palabra= input()
# convertir palabra a lista con lista_de_palabra = list(palabra)

# creamos otra lista llamada: palabras_ingresadas = []
# palabras_ingresadas.append(lsita_de_palabra)

# Probar un bucle que repita 3 veces el proceso siguiente:

# %%
# Solucion de Maria Paz:

# Definir una variable palabra = input()
# Convertir palabra a lista con lista_de_palabra = list(palabra)
# Creamos otra lista llamada: palabras_ingresadas = []
# palabras_ingresadas.append(lista_de_palabra)
# Probar un bucle que repita 3 veces el proceso seguiente: 

palabras_ingresadas = []
for i in range(3):
    palabra = input("Ingresar palabra")
    lista_usuario = list(palabra)
    palabras_ingresadas.append(lista_usuario)
    print(palabras_ingresadas)
# Out:
# [['h', 'o', 'l', 'a']]
# [['h', 'o', 'l', 'a'], ['c', 'h', 'a', 'u']]
# [['h', 'o', 'l', 'a'], ['c', 'h', 'a', 'u'], ['a', 'd', 'i', 'o', 's']]

# %% [markdown]
# ## Challenge 6 🤺 - 20m
#
# Dada la lista de ejemplo:
#
# lista = [['h', 'o', 'l', 'i', 's'], ['h', 'e', 'l', 'l', 'o'], ['h', 'a', 'l', 'l', 'o']]
#
# `Crear una función` que `imprima` una grilla (lista de listas), `una línea` por cada lista dentro de la lista principal.
#
# Ejemplo del resultado esperado:
#
# ```
# ['h', 'o', 'l', 'i', 's']
# ['h', 'e', 'l', 'l', 'o']
# ['h', 'a', 'l', 'l', 'o']
# ```

# %%
# Solucion de Juan Vicente:
lista=[['h', 'o', 'l', 'i', 's'], ['h', 'e', 'l', 'l', 'o'], ['h', 'a', 'l', 'l', 'o']]
def dar_enter():
    for i in lista:
        print(f"{i}\n")
dar_enter()
# Out:
# ['h', 'o', 'l', 'i', 's']
# ['h', 'e', 'l', 'l', 'o']
# ['h', 'a', 'l', 'l', 'o']

# %% [markdown]
# ##  Funcion Verificadora

# %% [markdown]
# - Crear una lista vacía `letras_verificadas` para las letras de la palabra luego de ser verificada
# - Definir la cantidad de letras de la palabra a encontrar
# - Si las letras existen en la palabra a encontrar y sus posiciones coinciden: encerrar en corchetes `[]` y agregar al resultado
# - Si las letras existen en la palabra a encontrar pero sus posiciones no coinciden: encerrar en parentesis `()` y agregar al resultado
# - Si no se cumple ninguna de las anteriores, agregar la letra a la lista vacía sin modificaciones
# - Retornar el resultado

# %%
letras_verificadas = []
cantidad_letras = 5

def verificador_palabra(palabra_ingresada, palabra_secreta):
    for i in range(cantidad_letras):
        las_palabras_son_iguales = palabra_ingresada[i] == palabra_secreta[i] # True o False
        la_letra_existe_en_la_palabra = palabra_ingresada[i] in palabra_secreta 
        
        if las_palabras_son_iguales:
            letras_verificadas.append(f"[{palabra_ingresada[i]}]")
        elif la_letra_existe_en_la_palabra:
            letras_verificadas.append(f"({palabra_ingresada[i]})")
        else:
            letras_verificadas.append(palabra_ingresada[i])
    
    return letras_verificadas

verificador_palabra('holas', 'calor')
# Out:
# ['h', '(o)', '[l]', '(a)', 's']

# %% [markdown]
# ### Intentos

# %%
# definir la cantidad de intentos = variable
intentos = 0

while intentos < 6:
    print(f"te quedan {6 - intentos} intentos")
    intentos = intentos + 1
    palabra_ingresada = input("Ingrese una palabra")
    print(f"la palabra ingresada es: {palabra_ingresada}")
